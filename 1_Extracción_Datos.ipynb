# %% [markdown]
# <a href="https://colab.research.google.com/github/Saulcuervo03/Repositoriosaul1/blob/main/1_Extracci%C3%B3n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#Cargar archivos csv desde equipo
from google.colab import files 
files.upload()

# %%
#Convertir en dataframe
df= pd.read_csv("file.csv")
df

# %%
#Imprimimos las primeras filas del Dataframe
df.head(5)
# Out:
#    Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0     2005          1           Nacional  Hombres
# 1     2005          1           Nacional  Mujeres
# 2     2005          1     Aguascalientes  Hombres
# 3     2005          1     Aguascalientes  Mujeres
# 4     2005          1    Baja California  Hombres
#
#   Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                         4384907          26597801
# 1                                         2690296          14843275
# 2                                           56407            246177
# 3                                           28430            145656
# 4                                          167651            768989
#
#   Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                        16.485975660000000000000
# 1                        18.124679360000000000000
# 2                        22.913188480000000000000
# ...

# %% [markdown]
# FILTROS BÁSICOS PARA VARIABLES CUALITATIVAS

# %%
#Filtro por objeto
filtro1=df[df["Sexo"] == "Hombres"]
filtro1

# %%
#Filtro por filas
filtro2= df.iloc[0:99,: ]
#filtro2=df.iloc[[1000, 2000, 3000], :] #filas no consecutivas
filtro2

# %%
#Filtro por columnas
#filtro3=df.iloc[ :, 4:6]
filtro3=df.iloc[ : , [1,4,6]] #columnas no consecutivas
filtro3
# Out:
#       Trimestre Poblacion_ocupada_en_la_industria_manufacturera  \
# 0             1                                         4384907
# 1             1                                         2690296
# 2             1                                           56407
# 3             1                                           28430
# 4             1                                          167651
# ...         ...                                             ...
# 4549          1                                          107640
# 4550          1                                          101992
# 4551          1                                           82759
# 4552          1                                           44105
# 4553          1                                           39472
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                           16.485975660000000000000
# 1                           18.124679360000000000000
# ...

# %%
#Filtro por columnas y por filas
filtro_mix=df.iloc[ [10,20,50] , 2:5]
#filtro_mix=df.iloc[ : , [1,4,6]] #columnas no consecutivas
filtro_mix

# %%
#Filtro de filas vs columnas
#Paso 1: Leemos el contenido del archivo
from google.colab import files
uploaded=files.upload()
df =pd.read_csv(io.BytesIO(uploaded['file.csv']), index_col=2)
df
# Out:
#      <input type="file" id="files-9d7cfa06-8806-4ad5-bcb7-6ace3ea71d3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d7cfa06-8806-4ad5-bcb7-6ace3ea71d3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Paso 2: Aplicammos el filtro de filas vs columnas
filtro4=df.loc[["Puebla","Veracruz"], ["Poblacion_ocupada_en_la_industria_manufacturera"]]
filtro4
# Out:
#                    Poblacion_ocupada_en_la_industria_manufacturera
# Entidad_Federativa
# Puebla                                                      230487
# Puebla                                                      188720
# Puebla                                                      236459
# Puebla                                                      190831
# Puebla                                                      233484
# ...                                                            ...
# Veracruz                                                    115123
# Veracruz                                                    173180
# Veracruz                                                    106314
# Veracruz                                                    185815
# Veracruz                                                    107640
#
# [276 rows x 1 columns]

# %%
#Filtro por cabecera
filtro5=df.head() #.head() imprime los primeros 5
filtro5
# Out:
#                     Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional               2005          1  Hombres
# Nacional               2005          1  Mujeres
# Aguascalientes         2005          1  Hombres
# Aguascalientes         2005          1  Mujeres
# Baja California        2005          1  Hombres
#
#                    Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                   4384907
# Nacional                                                   2690296
# Aguascalientes                                               56407
# Aguascalientes                                               28430
# Baja California                                             167651
#
#                    Poblaci n_ocupada  \
# Entidad_Federativa
# Nacional                    26597801
# Nacional                    14843275
# Aguascalientes                246177
# Aguascalientes                145656
# ...

# %% [markdown]
# FILTROS BÁSICOS PARA VARIABLES CUANTITATIVAS

# %%
#Filtro por comparacion
filtro6=df[df["Trimestre"] >= 2]
filtro6
# Out:
#                     Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional               2005          2  Hombres
# Nacional               2005          2  Mujeres
# Aguascalientes         2005          2  Hombres
# Aguascalientes         2005          2  Mujeres
# Baja California        2005          2  Hombres
# ...                     ...        ...      ...
# Veracruz               2021          4  Mujeres
# Yucat n                2021          4  Hombres
# Yucat n                2021          4  Mujeres
# Zacatecas              2021          4  Hombres
# Zacatecas              2021          4  Mujeres
#
#                    Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                   4299545
# Nacional                                                   2715510
# Aguascalientes                                               57749
# Aguascalientes                                               27850
# ...

# %% [markdown]
# FILTROS BASICOS CON CONECTORES LOGICOS

# %%
#Filtro Y
filtro7=df[(df["Periodo"] == 2015) & (df["Sexo"] == "Hombres") & (df["Trimestre"] == 1)]
filtro7
# Out:
#                      Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional                2015          1  Hombres
# Aguascalientes          2015          1  Hombres
# Baja California         2015          1  Hombres
# Baja California Sur     2015          1  Hombres
# Campeche                2015          1  Hombres
# Coahuila                2015          1  Hombres
# Colima                  2015          1  Hombres
# Chiapas                 2015          1  Hombres
# Chihuahua               2015          1  Hombres
# Ciudad de M xico        2015          1  Hombres
# Durango                 2015          1  Hombres
# Guanajuato              2015          1  Hombres
# Guerrero                2015          1  Hombres
# Hidalgo                 2015          1  Hombres
# Jalisco                 2015          1  Hombres
# M xico                  2015          1  Hombres
# Michoac n               2015          1  Hombres
# Morelos                 2015          1  Hombres
# ...
